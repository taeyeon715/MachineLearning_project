# %%
## 의사결정나무

import pandas as pd

# 데이터셋 불러오기
df = pd.read_csv('bank-full.csv', delimiter=';')

# 범주형 변수 더미 변수로 변환
df = pd.get_dummies(df, columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'poutcome'])

# 수치형 변수 스케일링
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
df[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']] = scaler.fit_transform(df[['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']])

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import MinMaxScaler

# 데이터셋 불러오기
df = pd.read_csv('bank-full.csv', delimiter=';')

# 범주형 변수 더미 변수로 변환
df = pd.get_dummies(df, columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'poutcome', 'month'])

# 수치형 변수 스케일링
scaler = MinMaxScaler()
num_cols = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
df[num_cols] = scaler.fit_transform(df[num_cols])

# 입력 변수와 출력 변수 분리
X = df.drop('y', axis=1)
y = df['y']

# 훈련 데이터셋과 테스트 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 가지치기를 적용하지 않은 의사결정나무 모델 생성
clf1 = DecisionTreeClassifier(random_state=42)
clf1.fit(X_train, y_train)

# 가지치기를 적용한 의사결정나무 모델 생성
clf2 = DecisionTreeClassifier(random_state=42, ccp_alpha=0.01)  # ccp_alpha는 가지치기에 사용되는 complexity parameter입니다.
clf2.fit(X_train, y_train)

# 예측하기
y_pred1 = clf1.predict(X_test)
y_pred2 = clf2.predict(X_test)

# 정확도 출력
print("의사결정나무 모델 (가지치기 적용 전) 정확도 : {:.2f}%".format(accuracy_score(y_test, y_pred1) * 100))
print("의사결정나무 모델 (가지치기 적용 후) 정확도 : {:.2f}%".format(accuracy_score(y_test, y_pred2) * 100))
# Out:
# 의사결정나무 모델 (가지치기 적용 전) 정확도 : 87.50%
# 의사결정나무 모델 (가지치기 적용 후) 정확도 : 88.89%

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

# 학습 결과 평가
train_acc = dt_clf.score(x_train, y_train)
test_acc = dt_clf.score(x_test, y_test)
print("Train Accuracy : ", train_acc)
print("Test Accuracy : ", test_acc)

# 분류 모델 평가지표 계산
y_pred = dt_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
matrix = confusion_matrix(y_test, y_pred)

print('Accuracy: ', format(accuracy,'.2f'))
print('Recall: ', format(recall,'.2f'))
print('Precision: ', format(precision,'.2f'))
print('F1_score: ', format(f1,'.2f'))
print('Confusion Matrix:\n', matrix)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [8], in <cell line: 4>()
#       1 from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
#       3 # 학습 결과 평가
# ----> 4 train_acc = dt_clf.score(x_train, y_train)
#       5 test_acc = dt_clf.score(x_test, y_test)
#       6 print("Train Accuracy : ", train_acc)
#
# NameError: name 'dt_clf' is not defined

# %%
from sklearn.tree import DecisionTreeClassifier, plot_tree
import matplotlib.pyplot as plt

# 의사결정나무 모델 학습
model = DecisionTreeClassifier()
model.fit(X_train, y_train)

# 의사결정나무 시각화
plt.figure(figsize=(20, 10))
plot_tree(model, feature_names=X.columns, class_names=['0', '1'], filled=True)
plt.show()

# %%
from sklearn.tree import export_graphviz
import graphviz

# 의사결정나무 모델 시각화 (가지치기 적용 전)
dot_data = export_graphviz(clf1, out_file=None, 
                           feature_names=X.columns,  
                           class_names=['No', 'Yes'],  
                           filled=True, rounded=True,  
                           special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render('decision_tree_before_pruning')

# 의사결정나무 모델 시각화 (가지치기 적용 후)
dot_data = export_graphviz(clf2, out_file=None, 
                           feature_names=X.columns,  
                           class_names=['No', 'Yes'],  
                           filled=True, rounded=True,  
                           special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render('decision_tree_after_pruning')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      80     else:
# ---> 81         proc = subprocess.run(cmd, **kwargs)
#      82 except OSError as e:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\subprocess.py:501, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     499     kwargs['stderr'] = PIPE
# --> 501 with Popen(*popenargs, **kwargs) as process:
#     502     try:
#
# ...

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix
from sklearn.preprocessing import MinMaxScaler

# 데이터셋 불러오기
df = pd.read_csv('bank-full.csv', delimiter=';')

# 범주형 변수 더미 변수로 변환
df = pd.get_dummies(df, columns=['job', 'marital', 'education', 'default', 'housing', 'loan', 'contact', 'poutcome', 'month'])

# 수치형 변수 스케일링
scaler = MinMaxScaler()
num_cols = ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']
df[num_cols] = scaler.fit_transform(df[num_cols])

# 입력 변수와 출력 변수 분리
X = df.drop('y', axis=1)
y = df['y']

# 훈련 데이터셋과 테스트 데이터셋 분리
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# 가지치기를 적용한 의사결정나무 모델 생성
dt_clf = DecisionTreeClassifier(random_state=42, ccp_alpha=0.01)  # ccp_alpha는 가지치기에 사용되는 complexity parameter입니다.
dt_clf.fit(X_train, y_train)

# 예측하기
y_pred = dt_clf.predict(X_test)

from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, confusion_matrix

# 분류 모델 평가지표 계산
y_pred = clf2.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
recall = recall_score(y_test, y_pred, pos_label='yes')
precision = precision_score(y_test, y_pred, pos_label='yes')
f1 = f1_score(y_test, y_pred, pos_label='yes')
matrix = confusion_matrix(y_test, y_pred)

# 결과 출력
print('Accuracy: ', format(accuracy,'.2f'))
print('Recall: ', format(recall,'.2f'))
print('Precision: ', format(precision,'.2f'))
print('F1_score: ', format(f1,'.2f'))
print('Confusion Matrix:\n', matrix)
# Out:
# Accuracy:  0.89
# Recall:  0.15
# Precision:  0.62
# F1_score:  0.24
# Confusion Matrix:
#  [[11815   151]
#  [ 1356   242]]

# %%
# !pip uninstall dtreeviz

# %%
# !pip install dtreeviz

# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier
from dtreeviz.trees import dtreeviz # dtreeviz 패키지 임포트

# 데이터셋 로드
iris = load_iris()
X, y = iris.data, iris.target
feature_names = iris.feature_names

# 모델 훈련
clf = DecisionTreeClassifier(max_depth=2)
clf.fit(X, y)

# 시각화
viz = dtreeviz(clf, X, y,
               target_name='target',
               feature_names=feature_names,
               class_names=list(iris.target_names))
viz
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Input In [5], in <cell line: 3>()
#       1 from sklearn.datasets import load_iris
#       2 from sklearn.tree import DecisionTreeClassifier
# ----> 3 from dtreeviz.trees import dtreeviz # dtreeviz 패키지 임포트
#       5 # 데이터셋 로드
#       6 iris = load_iris()
#
# ImportError: cannot import name 'dtreeviz' from 'dtreeviz.trees' (C:\Users\dlxod\AppData\Local\Programs\Python\Python310\lib\site-packages\dtreeviz\trees.py)
